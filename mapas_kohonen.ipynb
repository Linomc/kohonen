# %% [markdown]
# ## Verificando se o notebook está no ambiente virtual

# %%
! which python

# %% [markdown]
# # Iniciando Estudo dos mapas de Kohonen

# %%
# !pip install -U som-learn
# !pip install numpy
# !pip install matplotlib
# !pip install somoclu
# !pip install collections
# !pip install somlearn
# !pip install sklearn-som
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: som-learn in /home/lino/.local/lib/python3.10/site-packages (0.1.1)
# Requirement already satisfied: scipy>=0.17 in /home/lino/.local/lib/python3.10/site-packages (from som-learn) (1.11.3)
# Requirement already satisfied: numpy>=1.1 in /home/lino/.local/lib/python3.10/site-packages (from som-learn) (1.25.1)
# Requirement already satisfied: scikit-learn>=0.21 in /home/lino/.local/lib/python3.10/site-packages (from som-learn) (1.3.2)
# Requirement already satisfied: matplotlib>=3.0 in /home/lino/.local/lib/python3.10/site-packages (from som-learn) (3.7.2)
# Requirement already satisfied: somoclu==1.7.5 in /home/lino/.local/lib/python3.10/site-packages (from som-learn) (1.7.5)
# Requirement already satisfied: contourpy>=1.0.1 in /home/lino/.local/lib/python3.10/site-packages (from matplotlib>=3.0->som-learn) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /home/lino/.local/lib/python3.10/site-packages (from matplotlib>=3.0->som-learn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/lino/.local/lib/python3.10/site-packages (from matplotlib>=3.0->som-learn) (4.41.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/lino/.local/lib/python3.10/site-packages (from matplotlib>=3.0->som-learn) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /home/lino/.local/lib/python3.10/site-packages (from matplotlib>=3.0->som-learn) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /home/lino/.local/lib/python3.10/site-packages (from matplotlib>=3.0->som-learn) (10.0.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /usr/lib/python3/dist-packages (from matplotlib>=3.0->som-learn) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7 in /home/lino/.local/lib/python3.10/site-packages (from matplotlib>=3.0->som-learn) (2.8.2)
# Requirement already satisfied: joblib>=1.1.1 in /home/lino/.local/lib/python3.10/site-packages (from scikit-learn>=0.21->som-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/lino/.local/lib/python3.10/site-packages (from scikit-learn>=0.21->som-learn) (3.2.0)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.7->matplotlib>=3.0->som-learn) (1.16.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: numpy in /home/lino/.local/lib/python3.10/site-packages (1.25.1)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: matplotlib in /home/lino/.local/lib/python3.10/site-packages (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in /home/lino/.local/lib/python3.10/site-packages (from matplotlib) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /home/lino/.local/lib/python3.10/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/lino/.local/lib/python3.10/site-packages (from matplotlib) (4.41.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/lino/.local/lib/python3.10/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in /home/lino/.local/lib/python3.10/site-packages (from matplotlib) (1.25.1)
# Requirement already satisfied: packaging>=20.0 in /home/lino/.local/lib/python3.10/site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /home/lino/.local/lib/python3.10/site-packages (from matplotlib) (10.0.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /usr/lib/python3/dist-packages (from matplotlib) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7 in /home/lino/.local/lib/python3.10/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: somoclu in /home/lino/.local/lib/python3.10/site-packages (1.7.5)
# Requirement already satisfied: numpy in /home/lino/.local/lib/python3.10/site-packages (from somoclu) (1.25.1)
# Requirement already satisfied: matplotlib in /home/lino/.local/lib/python3.10/site-packages (from somoclu) (3.7.2)
# Requirement already satisfied: scipy in /home/lino/.local/lib/python3.10/site-packages (from somoclu) (1.11.3)
# Requirement already satisfied: contourpy>=1.0.1 in /home/lino/.local/lib/python3.10/site-packages (from matplotlib->somoclu) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /home/lino/.local/lib/python3.10/site-packages (from matplotlib->somoclu) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/lino/.local/lib/python3.10/site-packages (from matplotlib->somoclu) (4.41.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/lino/.local/lib/python3.10/site-packages (from matplotlib->somoclu) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /home/lino/.local/lib/python3.10/site-packages (from matplotlib->somoclu) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /home/lino/.local/lib/python3.10/site-packages (from matplotlib->somoclu) (10.0.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /usr/lib/python3/dist-packages (from matplotlib->somoclu) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7 in /home/lino/.local/lib/python3.10/site-packages (from matplotlib->somoclu) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.7->matplotlib->somoclu) (1.16.0)
# Defaulting to user installation because normal site-packages is not writeable
# ERROR: Could not find a version that satisfies the requirement collections (from versions: none)
# ERROR: No matching distribution found for collections
# Defaulting to user installation because normal site-packages is not writeable
# ERROR: Could not find a version that satisfies the requirement somlearn (from versions: none)
# ERROR: No matching distribution found for somlearn
# Defaulting to user installation because normal site-packages is not writeable
# Collecting sklearn-som
#   Using cached sklearn_som-1.1.0-py3-none-any.whl (6.7 kB)
# Requirement already satisfied: numpy in /home/lino/.local/lib/python3.10/site-packages (from sklearn-som) (1.25.1)
# Installing collected packages: sklearn-som
# Successfully installed sklearn-som-1.1.0

# %%
from sklearn_som.som import SOM
from sklearn import datasets

iris = datasets.load_iris()
iris_data = iris.data[:, :2]
iris_label = iris.target

# %%
iris_som = SOM(m=3, n=1, dim=2)
iris_som.fit(iris_data)
predictions = iris_som.predict(iris_data)

# %%
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap

fig, ax = plt.subplots(nrows=2, ncols=1, figsize=(5,7))
x=iris_data[:,0]
y=iris_data[:,1]
colors = ['red','green', 'blue']

ax[0].scatter(x,y, c=iris_label, cmap=ListedColormap(colors))
ax[0].title.set_text('classes')
ax[1].scatter(x,y, c=predictions, cmap=ListedColormap(colors))
ax[1].title.set_text('SOM')
